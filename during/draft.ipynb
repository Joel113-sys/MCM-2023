# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

from wordfreq import zipf_frequency
from wordfreq import word_frequency
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch import nn
import os
# enable this line if you encounter bugs on GPU
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"


np.random.seed(3314)
torch.manual_seed(3314)

# GPU operations have a separate seed we also want to set
if torch.cuda.is_available(): 
    torch.cuda.manual_seed(3314)
    torch.cuda.manual_seed_all(3314)
    
# Additionally, some operations on a GPU are implemented stochastic for efficiency
# We want to ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.determinstic = True
torch.backends.cudnn.benchmark = False


device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
file = open("valid-wordle-words.txt")
words = file.read().split()
df = pd.read_excel("Problem_C_Data_Wordle(1).xlsx")
subwords = df["Word"]
avgscores = df["Average Score"]
fullscores = df[
    [
        "1 try",
        "2 tries",
        "3 tries",
        "4 tries",
        "5 tries",
        "6 tries",
        "7 or more tries (X)",
    ]
]

CZERO = ord("a")

# %%
wordfreq = np.asarray(
    [word_frequency(words[i], "en") for i in range(len(words))], dtype=np.float64
)
maxfreq = max(wordfreq)
wordfreq = wordfreq / maxfreq
wordfreq = 1 / (1 + np.exp(-(wordfreq - 0.5) * 3))

avgscores = np.asarray(avgscores) - min(avgscores)
avgscores = avgscores / max(avgscores)

fullscores = np.asarray(fullscores)
fullscores = fullscores.T / (np.sum(fullscores, axis=1))
fullscores = fullscores.T
fullscores=fullscores[:,2:]


charpos = np.zeros((26, 6))
for i in range(len(words)):
    for j in range(5):
        charpos[ord(words[i][j]) - CZERO][j] += wordfreq[i]
        charpos[ord(words[i][j]) - CZERO][5] += wordfreq[i]


charcombo = np.zeros((26, 26))
for i in range(len(words)):
    for j in range(4):
        a = ord(words[i][j]) - ord("a")
        b = ord(words[i][j + 1]) - ord("a")
        charcombo[a][b] += wordfreq[i]

# %%
def syllable_count(word):
    word = word.lower()
    count = 0
    vowels = "aeiouy"
    if word[0] in vowels:
        count += 1
    for index in range(1, len(word)):
        if word[index] in vowels and word[index - 1] not in vowels:
            count += 1
    if word.endswith("e"):
        count -= 1
    if count == 0:
        count += 1
    return count

def getfeaturefq(word):
    # charnumber
    f0 = 0
    for j in range(5):
        same = False
        for k in range(j):
            if word[k] == word[j]:
                same = True
                break
        if not same:
            f0 += 1
    dummy = np.zeros((5))
    dummy[f0 - 1] = 1

    # charfeq
    f1 = 0
    for i in range(5):
        f1 += charpos[ord(word[i]) - ord("a")][5]
    f1 /= np.sum(charpos[:, -1])

    # charpos
    f2 = 0
    for i in range(5):
        f2 += charpos[ord(word[i]) - ord("a")][i]
    f2 /= np.sum(charpos[:, 0]) * 5

    # charcombo
    f3 = 0
    for i in range(4):
        a = ord(word[i]) - ord("a")
        b = ord(word[i + 1]) - ord("a")
        f3 += charcombo[a][b]
    f3 /= np.sum(charcombo)

    f4 = syllable_count(word)

    f5 = zipf_frequency(word, "en")
    f6 = word_frequency(word, "en")

    lo = 0
    hi = len(words) - 1
    while hi > lo:
        mid = (lo + hi) // 2
        if words[mid] < word:
            lo = mid + 1
        else:
            hi = mid
    f7 = wordfreq[lo]

    return np.concatenate((dummy, np.asarray([f1, f2, f3, f4, f5, f6, f7])), axis=0)
    # return np.asarray([f1, f2, f3, f4, f5, f6, f7])

# %%
class MyDataset(Dataset):

    def __init__(self, x, y):
        self.x = torch.FloatTensor(x)
        self.y = torch.unsqueeze(torch.FloatTensor(y),1)
        # self.y = torch.FloatTensor(y)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

    def __len__(self):
        return len(self.x)

# %%
features = np.array([getfeaturefq(word) for word in subwords])
target = np.array(avgscores)

train_data = MyDataset(features[0:300], target[0:300])
test_data = MyDataset(features[300:359], target[300:359])
train_dataloader = DataLoader(dataset=train_data, batch_size=10,shuffle=True)
test_dataloader = DataLoader(dataset=test_data, batch_size=10,shuffle=True)

# %%
def train_one_epoch(model, criterion, optimizer, train_dataloader, train_size):
    model.train()
    train_loss = 0.0
    for x, y in train_dataloader:
        x, y = x.to(device), y.to(device)
        batch_size = x.shape[0]

        y_pred = model(x)

        loss = criterion(y_pred, y)

        loss.backward()

        optimizer.step()

        optimizer.zero_grad()

        train_loss += loss.item() * batch_size

    train_loss = train_loss / train_size
    return train_loss


def test_one_epoch(model, criterion, test_dataloader, test_size):
    # overall accuracy of the model
    correct = 0
    test_loss = 0.0
    model.eval()

    with torch.no_grad():
        for x, y in test_dataloader:
            batch_size = x.shape[0]
            x, y = x.to(device), y.to(device)

            log_prob = model(x)

            loss = criterion(log_prob, y)

            predicted = torch.argmax(log_prob, dim=1)

            test_loss += loss.item() * batch_size

            correct += (predicted == y).sum().item()
    test_loss = test_loss / test_size
    test_acc = 100 * correct / test_size
    return test_loss, test_acc

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, xsize, ysize):
        super(NeuralNetwork, self).__init__()
        const=64
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(xsize, const),
            nn.ReLU(),
            nn.Linear(const,const),
            nn.ReLU(),
            nn.Linear(const, ysize),
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits


model = NeuralNetwork(len(features[0]), 1).to(device)

# %%
epochs = 1200
batch_size = 150

# Defined in Task 3.1
model = NeuralNetwork(len(features[0]), 1).to(device)

# Defined in Task 3.2
train_dataloader = DataLoader(dataset=train_data, batch_size=10,shuffle=True)
test_dataloader = DataLoader(dataset=test_data, batch_size=10,shuffle=True)

criterion = nn.MSELoss() # we define the loss function to be NLL
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) # use Adam optimizer

train_losses = []
test_losses = []

for epoch in range(1, epochs + 1): 
    # Defined in Task 3.3
    train_loss = train_one_epoch(model, criterion, optimizer, train_dataloader, len(train_data))
    test_loss, test_acc = test_one_epoch(model, criterion, test_dataloader, len(test_data))

    train_losses.append(train_loss)
    test_losses.append(test_loss)

    print(
        'Epoch: [{:4d}] | * training loss : {:.3f} | o testing loss : {:.3f} | + testing acc. {:.2f} %'
        .format(epoch, train_loss, test_loss, test_acc))
# Out:
# Epoch: [   1] | * training loss : 0.044 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [   2] | * training loss : 0.022 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [   3] | * training loss : 0.018 | o testing loss : 0.014 | + testing acc. 0.00 %
# Epoch: [   4] | * training loss : 0.018 | o testing loss : 0.014 | + testing acc. 0.00 %
# Epoch: [   5] | * training loss : 0.017 | o testing loss : 0.012 | + testing acc. 0.00 %
# Epoch: [   6] | * training loss : 0.017 | o testing loss : 0.012 | + testing acc. 0.00 %
# Epoch: [   7] | * training loss : 0.016 | o testing loss : 0.011 | + testing acc. 0.00 %
# Epoch: [   8] | * training loss : 0.016 | o testing loss : 0.011 | + testing acc. 0.00 %
# Epoch: [   9] | * training loss : 0.018 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [  10] | * training loss : 0.016 | o testing loss : 0.011 | + testing acc. 0.00 %
# Epoch: [
| * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1038] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1039] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1040] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1041] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1042] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1043] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1044] | * training loss : 0.007 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1045] | * training loss : 0.008 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1046] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1047] | * training loss : 0.008 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1048] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1049] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1050] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1051] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1052] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1053] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1054] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1055] | * training loss : 0.008 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1056] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1057] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1058] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1059] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1060] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1061] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1062] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1063] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1064] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1065] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1066] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1067] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1068] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1069] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1070] | * training loss : 0.007 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1071] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1072] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1073] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1074] | * training loss : 0.007 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1075] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1076] | * training loss : 0.008 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1077] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1078] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1079] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1080] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1081] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1082] | * training loss : 0.008 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1083] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1084] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1085] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1086] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1087] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1088] | * training loss : 0.008 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1089] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1090] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1091] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1092] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1093] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1094] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1095] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1096] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1097] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1098] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1099] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1100] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1101] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1102] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1103] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1104] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1105] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1106] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1107] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1108] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1109] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1110] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1111] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1112] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1113] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1114] | * training loss : 0.008 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1115] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1116] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1117] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1118] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1119] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1120] | * training loss : 0.007 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1121] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1122] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1123] | * training loss : 0.006 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1124] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1125] | * training loss : 0.006 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1126] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1127] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1128] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1129] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1130] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1131] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1132] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1133] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1134] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1135] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1136] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1137] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1138] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1139] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1140] | * training loss : 0.007 | o testing loss : 0.015 | + testing acc. 0.00 %
# Epoch: [1141] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1142] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1143] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1144] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1145] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1146] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1147] | * training loss : 0.006 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1148] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1149] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1150] | * training loss : 0.006 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1151] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1152] | * training loss : 0.006 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1153] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1154] | * training loss : 0.006 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1155] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1156] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1157] | * training loss : 0.007 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1158] | * training loss : 0.008 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1159] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1160] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1161] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1162] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1163] | * training loss : 0.006 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1164] | * training loss : 0.008 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1165] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1166] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1167] | * training loss : 0.007 | o testing loss : 0.019 | + testing acc. 0.00 %
# Epoch: [1168] | * training loss : 0.007 | o testing loss : 0.019 | + testing acc. 0.00 %
# Epoch: [1169] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1170] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1171] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1172] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1173] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1174] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1175] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1176] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1177] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1178] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1179] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1180] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1181] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1182] | * training loss : 0.007 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1183] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1184] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1185] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1186] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1187] | * training loss : 0.006 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1188] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1189] | * training loss : 0.006 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1190] | * training loss : 0.006 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1191] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1192] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1193] | * training loss : 0.008 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1194] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1195] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1196] | * training loss : 0.007 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1197] | * training loss : 0.006 | o testing loss : 0.017 | + testing acc. 0.00 %
# Epoch: [1198] | * training loss : 0.007 | o testing loss : 0.016 | + testing acc. 0.00 %
# Epoch: [1199] | * training loss : 0.007 | o testing loss : 0.018 | + testing acc. 0.00 %
# Epoch: [1200] | * training loss : 0.007 | o testing loss : 0.018 | + testing acc. 0.00 %

# %%
prescore=model(torch.FloatTensor(features))
prescore=np.asarray(torch.detach(prescore.squeeze()))

pairs=np.asarray([prescore[0:300],avgscores[0:300]]).T

pairs=np.asarray(sorted(pairs,key=lambda e:e[1])).T


plt.plot(np.arange(300),pairs[0],pairs[1])
# Out:
# [<matplotlib.lines.Line2D at 0x2e586428df0>,
#  <matplotlib.lines.Line2D at 0x2e5863ad340>]

# %%
prescore=model(torch.FloatTensor(features))
prescore=np.asarray(torch.detach(prescore.squeeze()))

pairs=np.asarray([prescore[300:359],avgscores[300:359]]).T

pairs=np.asarray(sorted(pairs,key=lambda e:e[1])).T

plt.plot(np.arange(59),pairs[0],pairs[1])
# Out:
# [<matplotlib.lines.Line2D at 0x2e58619da00>,
#  <matplotlib.lines.Line2D at 0x2e58619d6a0>]
